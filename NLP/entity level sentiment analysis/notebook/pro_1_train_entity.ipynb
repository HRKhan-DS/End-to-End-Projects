# %% [markdown]
# # Project Name: Entity-Level Sentiment Analysis

# %% [markdown]
# # Requirements

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Read dataset

# %%
# Read CSV file into DataFrame
path = r"G:\DATA SCIENCE-25\Github\entity_senti_git\dataset\preprocess.csv"
df = pd.read_csv(path)

# Display DataFrame
df.head()
# Out:
#    Tweet_ID  Borderlands Sentiment  \
# 0      2401  Borderlands  Positive
# 1      2401  Borderlands  Positive
# 2      2401  Borderlands  Positive
# 3      2402  Borderlands  Positive
# 4      2402  Borderlands  Positive
#
#                                        Tweet_Content  Words_Per_Tweet
# 0  im getting on borderlands and i will kill you ...               10
# 1  im coming on borderlands and i will murder you...               10
# 2  im getting into borderlands and i can murder y...               10
# 3  So I spent a few hours making something for fu...               55
# 4  So I spent a couple of hours doing something f...               54

# %% [markdown]
# # Simple clean the data for entity recognation

# %%
import re

def clean_text(text):
    # Define the pattern to remove unwanted substrings and symbols
    pattern = r"[^a-zA-Z]+|\b[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Za-z]{2,}\b"
    
    # Remove unwanted patterns from the text using the defined pattern
    cleaned_text = re.sub(pattern, ' ', text)
    
    # Convert text to lowercase
    cleaned_text = cleaned_text.lower()
    
    
    return cleaned_text

# %%
df['Preprocess_text'] = df['Tweet_Content'].apply(clean_text)

# %%
df.head()
# Out:
#    Tweet_ID  Borderlands Sentiment  \
# 0      2401  Borderlands  Positive
# 1      2401  Borderlands  Positive
# 2      2401  Borderlands  Positive
# 3      2402  Borderlands  Positive
# 4      2402  Borderlands  Positive
#
#                                        Tweet_Content  Words_Per_Tweet  \
# 0  im getting on borderlands and i will kill you ...               10
# 1  im coming on borderlands and i will murder you...               10
# 2  im getting into borderlands and i can murder y...               10
# 3  So I spent a few hours making something for fu...               55
# 4  So I spent a couple of hours doing something f...               54
#
#                                      Preprocess_text
# 0  im getting on borderlands and i will kill you ...
# 1  im coming on borderlands and i will murder you...
# 2  im getting into borderlands and i can murder y...
# 3  so i spent a few hours making something for fu...
# 4  so i spent a couple of hours doing something f...

# %% [markdown]
# Import required modules
#
# !python -m spacy download en_core_web_sm

# %%
# !python -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.7.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.7.1/en_core_web_sm-3.7.1-py3-none-any.whl (12.8 MB)
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      --------------------------------------- 0.0/12.8 MB 487.6 kB/s eta 0:00:27
#      --------------------------------------- 0.1/12.8 MB 744.7 kB/s eta 0:00:18
#      --------------------------------------- 0.1/12.8 MB 847.9 kB/s eta 0:00:15
#       -------------------------------------- 0.2/12.8 MB 803.1 kB/s eta 0:00:16
#       -------------------------------------- 0.2/12.8 MB 915.1 kB/s eta 0:00:14
#       -------------------------------------- 0.3/12.8 MB 944.1 kB/s eta 0:00:14
#       -------------------------------------- 0.3/12.8 MB 944.1 kB/s eta 0:00:14
#       -------------------------------------- 0.3/12.8 MB 944.1 kB/s eta 0:00:14
#       -------------------------------------- 0.3/12.8 MB 944.1 kB/s eta 0:00:14
#       -------------------------------------- 0.3/12.8 MB 944.1 kB/s eta 0:00:14
#      - -------------------------------------- 0.6/12.8 MB 1.0 MB/s eta 0:00:13
#      - -------------------------------------- 0.6/12.8 MB 1.1 MB/s eta 0:00:12
#      -- ------------------------------------- 0.7/12.8 MB 1.1 MB/s eta 0:00:12
#      -- ------------------------------------- 0.7/12.8 MB 1.1 MB/s eta 0:00:12
#      -- ------------------------------------- 0.7/12.8 MB 1.1 MB/s eta 0:00:12
#      -- ------------------------------------- 0.7/12.8 MB 1.1 MB/s eta 0:00:12
#      -- ------------------------------------ 0.8/12.8 MB 969.8 kB/s eta 0:00:13
#      -- ------------------------------------- 1.0/12.8 MB 1.1 MB/s eta 0:00:11
#      ----------------------- ---------------- 7.6/12.8 MB 1.2 MB/s eta 0:00:05
#      ------------------------ --------------- 7.8/12.8 MB 1.2 MB/s eta 0:00:05
#      ------------------------ --------------- 7.9/12.8 MB 1.2 MB/s eta 0:00:05
#      ------------------------ --------------- 7.9/12.8 MB 1.2 MB/s eta 0:00:05
#      ------------------------ --------------- 8.0/12.8 MB 1.2 MB/s eta 0:00:05
#      ------------------------- -------------- 8.1/12.8 MB 1.2 MB/s eta 0:00:05
#      ------------------------- -------------- 8.1/12.8 MB 1.2 MB/s eta 0:00:05
#      ------------------------- -------------- 8.2/12.8 MB 1.2 MB/s eta 0:00:04
#      ------------------------- -------------- 8.2/12.8 MB 1.2 MB/s eta 0:00:04
#      ------------------------- -------------- 8.3/12.8 MB 1.2 MB/s eta 0:00:04
#      -------------------------- ------------- 8.3/12.8 MB 1.2 MB/s eta 0:00:04
#      -------------------------- ------------- 8.4/12.8 MB 1.2 MB/s eta 0:00:04
#      -------------------------- ------------- 8.4/12.8 MB 1.2 MB/s eta 0:00:04
#      -------------------------- ------------- 8.5/12.8 MB 1.2 MB/s eta 0:00:04
#      -------------------------- ------------- 8.5/12.8 MB 1.2 MB/s eta 0:00:04
#      -------------------------- ------------- 8.6/12.8 MB 1.2 MB/s eta 0:00:04
#      --------------------------- ------------ 8.7/12.8 MB 1.2 MB/s eta 0:00:04
#      --------------------------- ------------ 8.7/12.8 MB 1.2 MB/s eta 0:00:04
#      --------------------------- ------------ 8.8/12.8 MB 1.2 MB/s eta 0:00:04
#      --------------------------- ------------ 8.8/12.8 MB 1.2 MB/s eta 0:00:04
#      --------------------------- ------------ 8.9/12.8 MB 1.2 MB/s eta 0:00:04
#      --------------------------- ------------ 8.9/12.8 MB 1.2 MB/s eta 0:00:04
#      ---------------------------- ----------- 9.0/12.8 MB 1.2 MB/s eta 0:00:04
#      ---------------------------- ----------- 9.0/12.8 MB 1.2 MB/s eta 0:00:04
#      ---------------------------- ----------- 9.1/12.8 MB 1.2 MB/s eta 0:00:04
#      ---------------------------- ----------- 9.1/12.8 MB 1.2 MB/s eta 0:00:04
#      ---------------------------- ----------- 9.2/12.8 MB 1.2 MB/s eta 0:00:04
#      ---------------------------- ----------- 9.3/12.8 MB 1.2 MB/s eta 0:00:04
#      ----------------------------- ---------- 9.3/12.8 MB 1.2 MB/s eta 0:00:03
#      ----------------------------- ---------- 9.3/12.8 MB 1.2 MB/s eta 0:00:03
#      ----------------------------- ---------- 9.4/12.8 MB 1.2 MB/s eta 0:00:03
#      ----------------------------- ---------- 9.5/12.8 MB 1.2 MB/s eta 0:00:03
#      ----------------------------- ---------- 9.5/12.8 MB 1.2 MB/s eta 0:00:03
#      ----------------------------- ---------- 9.6/12.8 MB 1.2 MB/s eta 0:00:03
#      ------------------------------ --------- 9.6/12.8 MB 1.2 MB/s eta 0:00:03
#      ------------------------------ --------- 9.7/12.8 MB 1.2 MB/s eta 0:00:03
#      ------------------------------ --------- 9.7/12.8 MB 1.2 MB/s eta 0:00:03
#      ------------------------------ --------- 9.8/12.8 MB 1.2 MB/s eta 0:00:03
#      ------------------------------ --------- 9.8/12.8 MB 1.2 MB/s eta 0:00:03
#      ------------------------------ --------- 9.9/12.8 MB 1.2 MB/s eta 0:00:03
#      ------------------------------- -------- 10.0/12.8 MB 1.2 MB/s eta 0:00:03
#      ------------------------------- -------- 10.0/12.8 MB 1.2 MB/s eta 0:00:03
#      ------------------------------- -------- 10.1/12.8 MB 1.2 MB/s eta 0:00:03
#      ------------------------------- -------- 10.1/12.8 MB 1.2 MB/s eta 0:00:03
#      ------------------------------- -------- 10.2/12.8 MB 1.2 MB/s eta 0:00:03
#      ------------------------------- -------- 10.2/12.8 MB 1.2 MB/s eta 0:00:03
#      -------------------------------- ------- 10.3/12.8 MB 1.2 MB/s eta 0:00:03
#      -------------------------------- ------- 10.3/12.8 MB 1.2 MB/s eta 0:00:03
#      -------------------------------- ------- 10.4/12.8 MB 1.2 MB/s eta 0:00:03
#      -------------------------------- ------- 10.5/12.8 MB 1.2 MB/s eta 0:00:02
#      -------------------------------- ------- 10.5/12.8 MB 1.2 MB/s eta 0:00:02
#      -------------------------------- ------- 10.5/12.8 MB 1.2 MB/s eta 0:00:02
#      --------------------------------- ------ 10.6/12.8 MB 1.2 MB/s eta 0:00:02
#      --------------------------------- ------ 10.7/12.8 MB 1.2 MB/s eta 0:00:02
#      --------------------------------- ------ 10.7/12.8 MB 1.2 MB/s eta 0:00:02
#      --------------------------------- ------ 10.8/12.8 MB 1.2 MB/s eta 0:00:02
#      --------------------------------- ------ 10.8/12.8 MB 1.2 MB/s eta 0:00:02
#      --------------------------------- ------ 10.9/12.8 MB 1.2 MB/s eta 0:00:02
#      ---------------------------------- ----- 10.9/12.8 MB 1.2 MB/s eta 0:00:02
#      ---------------------------------- ----- 11.0/12.8 MB 1.2 MB/s eta 0:00:02
#      ---------------------------------- ----- 11.0/12.8 MB 1.2 MB/s eta 0:00:02
#      ---------------------------------- ----- 11.1/12.8 MB 1.2 MB/s eta 0:00:02
#      ---------------------------------- ----- 11.2/12.8 MB 1.2 MB/s eta 0:00:02
#      ---------------------------------- ----- 11.2/12.8 MB 1.2 MB/s eta 0:00:02
#      ----------------------------------- ---- 11.3/12.8 MB 1.2 MB/s eta 0:00:02
#      ----------------------------------- ---- 11.3/12.8 MB 1.2 MB/s eta 0:00:02
#      ----------------------------------- ---- 11.4/12.8 MB 1.2 MB/s eta 0:00:02
#      ----------------------------------- ---- 11.4/12.8 MB 1.2 MB/s eta 0:00:02
#      ----------------------------------- ---- 11.5/12.8 MB 1.2 MB/s eta 0:00:02
#      ------------------------------------ --- 11.5/12.8 MB 1.2 MB/s eta 0:00:02
#      ------------------------------------ --- 11.6/12.8 MB 1.2 MB/s eta 0:00:02
#      ------------------------------------ --- 11.6/12.8 MB 1.2 MB/s eta 0:00:01
#      ------------------------------------ --- 11.7/12.8 MB 1.2 MB/s eta 0:00:01
#      ------------------------------------ --- 11.7/12.8 MB 1.2 MB/s eta 0:00:01
#      ------------------------------------ --- 11.8/12.8 MB 1.2 MB/s eta 0:00:01
#      ------------------------------------ --- 11.8/12.8 MB 1.2 MB/s eta 0:00:01
#      ------------------------------------- -- 11.9/12.8 MB 1.2 MB/s eta 0:00:01
#      ------------------------------------- -- 12.0/12.8 MB 1.2 MB/s eta 0:00:01
#      ------------------------------------- -- 12.0/12.8 MB 1.2 MB/s eta 0:00:01
#      ------------------------------------- -- 12.1/12.8 MB 1.2 MB/s eta 0:00:01
#      ------------------------------------- -- 12.1/12.8 MB 1.2 MB/s eta 0:00:01
#      -------------------------------------- - 12.2/12.8 MB 1.2 MB/s eta 0:00:01
#      -------------------------------------- - 12.2/12.8 MB 1.2 MB/s eta 0:00:01
#      -------------------------------------- - 12.3/12.8 MB 1.2 MB/s eta 0:00:01
#      -------------------------------------- - 12.3/12.8 MB 1.2 MB/s eta 0:00:01
#      -------------------------------------- - 12.4/12.8 MB 1.2 MB/s eta 0:00:01
#      -------------------------------------- - 12.5/12.8 MB 1.2 MB/s eta 0:00:01
#      ---------------------------------------  12.5/12.8 MB 1.2 MB/s eta 0:00:01
#      ---------------------------------------  12.6/12.8 MB 1.2 MB/s eta 0:00:01
#      ---------------------------------------  12.6/12.8 MB 1.2 MB/s eta 0:00:01
#      ---------------------------------------  12.7/12.8 MB 1.2 MB/s eta 0:00:01
#      ---------------------------------------  12.7/12.8 MB 1.2 MB/s eta 0:00:01
#      ---------------------------------------  12.8/12.8 MB 1.2 MB/s eta 0:00:01
#      ---------------------------------------- 12.8/12.8 MB 1.2 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in g:\data science-25\github\entity_senti_git\venv_entity\lib\site-packages (from en-core-web-sm==3.7.1) (3.7.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in g:\data science-25\github\entity_senti_git\venv_entity\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in g:\data science-25\github\entity_senti_git\venv_entity\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in g:\data science-25\github\entity_senti_git\venv_entity\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in g:\data science-25\github\entity_senti_git\venv_entity\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in g:\data science-25\github\entity_senti_git\venv_entity\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in g:\data science-25\github\entity_senti_git\venv_entity\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in g:\data science-25\github\entity_senti_git\venv_entity\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in g:\data science-25\github\entity_senti_git\venv_entity\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in g:\data science-25\github\entity_senti_git\venv_entity\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in g:\data science-25\github\entity_senti_git\venv_entity\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in g:\data science-25\github\entity_senti_git\venv_entity\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.9.4)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in g:\data science-25\github\entity_senti_git\venv_entity\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in g:\data science-25\github\entity_senti_git\venv_entity\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.66.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in g:\data science-25\github\entity_senti_git\venv_entity\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in g:\data science-25\github\entity_senti_git\venv_entity\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.7.1)
# Requirement already satisfied: jinja2 in g:\data science-25\github\entity_senti_git\venv_entity\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.1.4)
# Requirement already satisfied: setuptools in g:\data science-25\github\entity_senti_git\venv_entity\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (69.5.1)
# Requirement already satisfied: packaging>=20.0 in g:\data science-25\github\entity_senti_git\venv_entity\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (24.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in g:\data science-25\github\entity_senti_git\venv_entity\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.4.0)
# Requirement already satisfied: numpy>=1.19.0 in g:\data science-25\github\entity_senti_git\venv_entity\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.26.4)
# Requirement already satisfied: language-data>=1.2 in g:\data science-25\github\entity_senti_git\venv_entity\lib\site-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.2.0)
# Requirement already satisfied: annotated-types>=0.4.0 in g:\data science-25\github\entity_senti_git\venv_entity\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.2 in g:\data science-25\github\entity_senti_git\venv_entity\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.18.2)
# Requirement already satisfied: typing-extensions>=4.6.1 in g:\data science-25\github\entity_senti_git\venv_entity\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in g:\data science-25\github\entity_senti_git\venv_entity\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in g:\data science-25\github\entity_senti_git\venv_entity\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in g:\data science-25\github\entity_senti_git\venv_entity\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in g:\data science-25\github\entity_senti_git\venv_entity\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2024.2.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in g:\data science-25\github\entity_senti_git\venv_entity\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in g:\data science-25\github\entity_senti_git\venv_entity\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.4)
# Requirement already satisfied: colorama in g:\data science-25\github\entity_senti_git\venv_entity\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in g:\data science-25\github\entity_senti_git\venv_entity\lib\site-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in g:\data science-25\github\entity_senti_git\venv_entity\lib\site-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in g:\data science-25\github\entity_senti_git\venv_entity\lib\site-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.1.5)
# Requirement already satisfied: marisa-trie>=0.7.7 in g:\data science-25\github\entity_senti_git\venv_entity\lib\site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.1.1)
# Installing collected packages: en-core-web-sm
#   Attempting uninstall: en-core-web-sm
#     Found existing installation: en_core_web_sm 2.2.5
#     Uninstalling en_core_web_sm-2.2.5:
#       Successfully uninstalled en_core_web_sm-2.2.5
# Successfully installed en-core-web-sm-3.7.1
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
import spacy
from spacy.tokens import Span

# Load SpaCy English model
nlp = spacy.load("en_core_web_sm")

# Define custom entities
custom_entities = ['Borderlands','Overwatch','Xbox(Xseries)','TomClancysGhostRecon','Dota2', 'CS-GO',
                   'AssassinsCreed','ApexLegends','LeagueOfLegends','Fortnite','Hearthstone','Battlefield',
                   'PlayerUnknownsBattlegrounds','PUBG','CallOfDuty','TomClancysRainbowSix','GrandTheftAuto(GTA)',
                   'Cyberpunk2077']

# Add custom entity ruler to the pipeline
ruler = nlp.add_pipe("entity_ruler")

# Define patterns for custom entities
patterns = [
    {"label": "PERSON", "pattern": [{"LOWER": "borderlands"}]},
    {"label": "PERSON", "pattern": [{"LOWER": "playerunknownsbattlegrounds"}]},
    {"label": "PERSON", "pattern": [{"LOWER": "tomclancysrainbowsix"}]},
    {"label": "PERSON", "pattern": [{"LOWER": "hearthstone"}]},
    {"label": "GAME", "pattern": [{"LOWER": "pubg"}]},
    {"label": "GAME", "pattern": [{"LOWER": "xbox(xseries)"}]},
    {"label": "GAME", "pattern": [{"LOWER": "overwatch"}]},
    {"label": "GAME", "pattern": [{"LOWER": "leagueoflegends"}]},
    {"label": "GAME", "pattern": [{"LOWER": "apexlegends"}]},
    {"label": "GAME", "pattern": [{"LOWER": "callofduty"}]},
    {"label": "GAME", "pattern": [{"LOWER": "battlefield"}]},
    {"label": "ORG", "pattern": [{"LOWER": "dota2"}]},
    {"label": "ORG", "pattern": [{"LOWER": "cs-go"}]},
    {"label": "ORG", "pattern": [{"LOWER": "assassinscreed"}]},
    {"label": "ORG", "pattern": [{"LOWER": "fortnite"}]},
    {"label": "ORG", "pattern": [{"LOWER": "grandtheftauto(gta)"}]},
    {"label": "ORG", "pattern": [{"LOWER": "cyberpunk2077"}]}
]

# Add patterns to the ruler
ruler.add_patterns(patterns)

# Function to perform entity recognition on a text
def entity_recognition(text):
    doc = nlp(text)
    entities = [(ent.text, ent.label_) for ent in doc.ents]
    return entities

# %% [markdown]
# # Evaluation of Entity

# %%
# Example usage
text = "Mr. @Harun is playing borderlands and Overwatch on Xbox(Xseries) and TomClancysGhostRecon."
preprocess = clean_text(text)
print(preprocess)
entities = entity_recognition(preprocess)
print(entities)
# Out:
# mr harun is playing borderlands and overwatch on xbox xseries and tomclancysghostrecon
# [('harun', 'PERSON'), ('borderlands', 'PERSON'), ('overwatch', 'GAME')]

# %%
#df['Entities'] = df['Preprocess_text'].apply(entity_recognition)

# %% [markdown]
# # Save the Entity dataset

# %%
df.to_csv(r"G:\DATA SCIENCE-25\Github\entity_senti_git\dataset\entity.csv", index=False)

# %% [markdown]
# # Preporcess for Sentiment Analysis

# %%
# Import required modules
#python -m spacy download en_core_web_sm

import spacy
import string
from spacy.lang.en.stop_words import STOP_WORDS

# Load the large spaCy model
nlp = spacy.load("en_core_web_sm")

# Access the default stop words from the loaded model
stop_words = nlp.Defaults.stop_words

# Define punctuation
punctuations = string.punctuation

# %%
# Creating our tokenizer function
def spacy_token(sentence):
    # Creating our token object, which is used to create documents with linguistic annotations.
    doc = nlp(sentence)

    # Lemmatizing each token and converting each token into lowercase
    mytokens = [word.lemma_.lower().strip() for word in doc]

    # Removing stop words and punctuation
    mytokens = [word for word in mytokens if word not in stop_words and word not in punctuations]
    
    # Joining tokens back into a sentence
    processed_sentence = " ".join(mytokens)

    # return preprocessed sentence
    return processed_sentence

# %%
# Apply the tokenizer function to the 'text' column and store the result in the 'tokenize' column
df['tokenize'] = df['Preprocess_text'].apply(spacy_token)
df.head()
# Out:
#    Tweet_ID  Borderlands Sentiment  \
# 0      2401  Borderlands  Positive
# 1      2401  Borderlands  Positive
# 2      2401  Borderlands  Positive
# 3      2402  Borderlands  Positive
# 4      2402  Borderlands  Positive
#
#                                        Tweet_Content  Words_Per_Tweet  \
# 0  im getting on borderlands and i will kill you ...               10
# 1  im coming on borderlands and i will murder you...               10
# 2  im getting into borderlands and i can murder y...               10
# 3  So I spent a few hours making something for fu...               55
# 4  So I spent a couple of hours doing something f...               54
#
#                                      Preprocess_text  \
# 0  im getting on borderlands and i will kill you ...
# 1  im coming on borderlands and i will murder you...
# 2  im getting into borderlands and i can murder y...
# 3  so i spent a few hours making something for fu...
# 4  so i spent a couple of hours doing something f...
#
#                                             tokenize
# 0                                  m borderland kill
# 1                           m come borderland murder
# 2                                m borderland murder
# 3  spend hour fun don t know huge borderland fan ...
# 4  spend couple hour fun don t know m huge border...

# %% [markdown]
# # Evaluation of spacy_token

# %%
# Example usage
text = "Mr. @Harun is playing borderlands and Overwatch on Xbox(Xseries) and TomClancysGhostRecon."
preprocess = clean_text(text)
spacy_text = spacy_token(preprocess)
print(spacy_text)
# Out:
# mr harun play borderland overwatch xbox xserie tomclancysghostrecon

# %% [markdown]
# # Save the spacy token text

# %%
df = df[df['tokenize'].apply(len) >3]

# %%
df = df.reset_index(drop=True)

# %% [markdown]
# # Save the spacy token text

# %%
df.to_csv(r"G:\DATA SCIENCE-25\Github\entity_sentiment_streamlit\dataset\spacy_token.csv", index=False)

# %% [markdown]
# # Text embedding

# %%
from sentence_transformers import SentenceTransformer,util
model = SentenceTransformer('all-MiniLM-L6-v2')

# %%
# Compute embeddings for the 'Text' column
embeddings = model.encode(df['tokenize'])

# %%
df['embeddings'] = embeddings.tolist()

# %% [markdown]
# # Model Evaluation

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
df['Sentiment'] = le.fit_transform(df['Sentiment'])

# %%
# Split the dataset into features (X) and target (y)
X = df['embeddings'].tolist()
y = df['Sentiment'].tolist()

from sklearn.model_selection import train_test_split

# Split the data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression()

lr.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# Evaluate the model on training and test data
y_pred_train = lr.predict(X_train)
y_pred_test = lr.predict(X_test)

accuracy_train = accuracy_score(y_train, y_pred_train)
accuracy_test = accuracy_score(y_test, y_pred_test)
cm = confusion_matrix(y_test, y_pred_test)

print("Accuracy on train set:", accuracy_train)
print("Accuracy on test set:", accuracy_test)
print("Confusion Matrix:\n", cm)
print("Classification Report:\n", classification_report(y_test, y_pred_test))
# Out:
# Accuracy on train set: 0.8235202248945807
# Accuracy on test set: 0.8193403298350824
# Confusion Matrix:
#  [[3580  668]
#  [ 778 2978]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.82      0.84      0.83      4248
#            1       0.82      0.79      0.80      3756
#
#     accuracy                           0.82      8004
#    macro avg       0.82      0.82      0.82      8004
# weighted avg       0.82      0.82      0.82      8004

# %% [markdown]
# # RandomForestClassifier

# %%
from sklearn.ensemble import RandomForestClassifier

# Train a RandomForestClassifier model
rf = RandomForestClassifier()

rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# Evaluate the model on training and test data
y_pred_train = rf.predict(X_train)
y_pred_test = rf.predict(X_test)

accuracy_train = accuracy_score(y_train, y_pred_train)
accuracy_test = accuracy_score(y_test, y_pred_test)
cm = confusion_matrix(y_test, y_pred_test)

print("Accuracy on train set:", accuracy_train)
print("Accuracy on test set:", accuracy_test)
print("Confusion Matrix:\n", cm)
print("Classification Report:\n", classification_report(y_test, y_pred_test))
# Out:
# Accuracy on train set: 0.9963454630641887
# Accuracy on test set: 0.9026736631684158
# Confusion Matrix:
#  [[3948  300]
#  [ 479 3277]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.89      0.93      0.91      4248
#            1       0.92      0.87      0.89      3756
#
#     accuracy                           0.90      8004
#    macro avg       0.90      0.90      0.90      8004
# weighted avg       0.90      0.90      0.90      8004

# %% [markdown]
# # Evaluation

# %%
import re

def clean_text(text):
    # Define the pattern to remove unwanted substrings and symbols
    pattern = r"[^a-zA-Z]+|\b[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Za-z]{2,}\b"
    
    # Remove unwanted patterns from the text using the defined pattern
    cleaned_text = re.sub(pattern, ' ', text)
    
    # Convert text to lowercase
    cleaned_text = cleaned_text.lower()
    
    
    return cleaned_text
import spacy
from spacy.tokens import Span

# Load SpaCy English model
nlp = spacy.load("en_core_web_sm")

# Define custom entities
custom_entities = ['Borderlands','Overwatch','Xbox(Xseries)','TomClancysGhostRecon','Dota2', 'CS-GO',
                   'AssassinsCreed','ApexLegends','LeagueOfLegends','Fortnite','Hearthstone','Battlefield',
                   'PlayerUnknownsBattlegrounds','PUBG','CallOfDuty','TomClancysRainbowSix','GrandTheftAuto(GTA)',
                   'Cyberpunk2077']

# Add custom entity ruler to the pipeline
ruler = nlp.add_pipe("entity_ruler")

# Define patterns for custom entities
patterns = [
    {"label": "PERSON", "pattern": [{"LOWER": "borderlands"}]},
    {"label": "PERSON", "pattern": [{"LOWER": "playerunknownsbattlegrounds"}]},
    {"label": "PERSON", "pattern": [{"LOWER": "tomclancysrainbowsix"}]},
    {"label": "PERSON", "pattern": [{"LOWER": "hearthstone"}]},
    {"label": "GAME", "pattern": [{"LOWER": "pubg"}]},
    {"label": "GAME", "pattern": [{"LOWER": "xbox(xseries)"}]},
    {"label": "GAME", "pattern": [{"LOWER": "overwatch"}]},
    {"label": "GAME", "pattern": [{"LOWER": "leagueoflegends"}]},
    {"label": "GAME", "pattern": [{"LOWER": "apexlegends"}]},
    {"label": "GAME", "pattern": [{"LOWER": "callofduty"}]},
    {"label": "GAME", "pattern": [{"LOWER": "battlefield"}]},
    {"label": "ORG", "pattern": [{"LOWER": "dota2"}]},
    {"label": "ORG", "pattern": [{"LOWER": "cs-go"}]},
    {"label": "ORG", "pattern": [{"LOWER": "assassinscreed"}]},
    {"label": "ORG", "pattern": [{"LOWER": "fortnite"}]},
    {"label": "ORG", "pattern": [{"LOWER": "grandtheftauto(gta)"}]},
    {"label": "ORG", "pattern": [{"LOWER": "cyberpunk2077"}]}
]

# Add patterns to the ruler
ruler.add_patterns(patterns)

# Function to perform entity recognition on a text
def entity_recognition(text):
    doc = nlp(text)
    entities = [(ent.text, ent.label_) for ent in doc.ents]
    return entities 

text = "Mr. @Harun is playing borderlands and Overwatch on Xbox(Xseries) and TomClancysGhostRecon."
preprocess = clean_text(text)

entities = entity_recognition(preprocess)
print(entities)

spacy_text = spacy_token(preprocess)


embeddings = model.encode(spacy_text)


# Predict sentiment using the trained model
predicted_sentiment = rf.predict(embeddings.reshape(1, -1))

# Map predicted sentiment label to human-readable format
sentiment_label = "Positive" if predicted_sentiment == 0 else "Negative"

print(f"Predicted Sentiment: {sentiment_label}")
# Out:
# [('harun', 'PERSON'), ('borderlands', 'PERSON'), ('overwatch', 'GAME')]
# Predicted Sentiment: Negative

# %%
# Deployment

# %%
import pickle

# Save the trained Random Forest model to a file
with open(r'G:\DATA SCIENCE-25\Github\entity_senti_git\model\rf.pkl', 'wb') as model_file:
    pickle.dump(rf, model_file)
